# %% [markdown]
# # Appendix A Dataset: House_Price

# %% [markdown]
# ## Linear Regression Models

# %%
import pandas as pd
from pathlib import Path

data_path = Path("../../data/raw/Appendix_A_data.xlsx")

myData = pd.read_excel(data_path, sheet_name="House_Price")

myData.head()
# Out:
#    Record  Sale_amount  Sale_date  Beds  Baths  Sqft_home  Sqft_lot  \
# 0       1       295000 2016-05-31     5   3.00       2020   38332.8
# 1       2       240000 2016-06-20     4   2.00       1498   54014.4
# 2       3       385000 2016-05-31     5   4.00       4000   85813.2
# 3       4       268000 2016-04-12     3   2.50       2283  118918.8
# 4       5       186000 2016-04-05     3   1.25       1527   15681.6
#
#             Type  Build_year      Town             University
# 0  Single Family        1976  Ames, IA  Iowa State University
# 1  Single Family        2002  Ames, IA  Iowa State University
# 2  Single Family        2001  Ames, IA  Iowa State University
# 3  Single Family        1972  Ames, IA  Iowa State University
# 4  Single Family        1975  Ames, IA  Iowa State University

# %%
# Filter data for Iowa State University
myData = myData.query("University =='Iowa State University'")

# Convert house type into dummy variable, Single Family = 1, Non Single Family = 0
myData['Type'] = myData['Type'].apply(lambda x: 1 if x == 'Single Family' else 0)

# Determining age of home
from datetime import datetime
myData['Age'] = datetime.now().year - myData['Build_year']

myData.head()
# Out:
#    Record  Sale_amount  Sale_date  Beds  Baths  Sqft_home  Sqft_lot  Type  \
# 0       1       295000 2016-05-31     5   3.00       2020   38332.8     1
# 1       2       240000 2016-06-20     4   2.00       1498   54014.4     1
# 2       3       385000 2016-05-31     5   4.00       4000   85813.2     1
# 3       4       268000 2016-04-12     3   2.50       2283  118918.8     1
# 4       5       186000 2016-04-05     3   1.25       1527   15681.6     1
#
#    Build_year      Town             University  Age
# 0        1976  Ames, IA  Iowa State University   50
# 1        2002  Ames, IA  Iowa State University   24
# 2        2001  Ames, IA  Iowa State University   25
# 3        1972  Ames, IA  Iowa State University   54
# 4        1975  Ames, IA  Iowa State University   51

# %%
# Descriptive statistics for Ames dataset
desc_stats = myData[['Sale_amount', 'Beds', 'Baths', 'Sqft_home', 'Sqft_lot', 'Age']].describe().T
desc_stats
desc_stats_rounded = desc_stats.round(2)
desc_stats_rounded
# Out:
#              count       mean        std      min       25%       50%  \
# Sale_amount  211.0  229548.42  110646.75  51000.0  160000.0  215000.0
# Beds         211.0       3.31       0.90      1.0       3.0       3.0
# Baths        211.0       2.35       0.87      1.0       2.0       2.0
# Sqft_home    211.0    1645.29     716.55    630.0    1218.0    1521.0
# Sqft_lot     211.0   19102.07   40308.16   1015.0    8094.0   10159.0
# Age          211.0      55.80      30.48     10.0      30.0      53.0
#
#                   75%       max
# Sale_amount  265050.0  925000.0
# Beds              4.0       6.0
# Baths             3.0       5.0
# Sqft_home      1916.0    6974.0
# Sqft_lot      13068.0  413820.0
# Age              73.0     146.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(myData['Sale_amount'], kde=True, bins=30)
plt.title('Distribution of Sale Amount')
plt.xlabel('Sale Amount ($)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(myData['Sqft_home'], kde=True, bins=30)
plt.title('Distribution of Home Square Footage')
plt.xlabel('Sqft_home')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(myData['Sqft_lot'], kde=True, bins=30)
plt.title('Distribution of Lot Square Footage')
plt.xlabel('Sqft_lot')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x=myData['Beds'])
plt.title('Distribution of Bedroom Count')
plt.xlabel('Beds')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.histplot(myData['Baths'], kde=True, bins=20)
plt.title('Distribution of Bathroom Count')
plt.xlabel('Baths')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr = myData[['Sale_amount', 'Beds', 'Baths', 'Sqft_home', 'Sqft_lot', 'Age', 'Type']].corr()

# Plot heatmap
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title('Correlation Heatmap for Ames Dataset')
plt.show()

# %% [markdown]
# ### Model 1: Sale_amount ~ Beds + Baths + Sqft_home + Sqft_lot + Type + Age

# %%
# Obtaining regression equation using all predictor variables
import statsmodels.formula.api as smf
import numpy as np

Model1 = smf.ols('Sale_amount ~ Beds + Baths + Sqft_home + Sqft_lot + Type + Age', data = myData).fit()

print(Model1.summary())

# Obtaining residuals
Model_Residuals = Model1.resid

import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.scatterplot(x =myData.Record, y = Model_Residuals, color = 'Chocolate')

# Add horizontal line at y=0
plt.axhline(y=0, color='black', linestyle='--')

# Set labels
ax.set(xlabel = 't', ylabel ='e');

# Show the plot
plt.show()

#Calculating robust standard error
Robust_Results = Model1.get_robustcov_results(cov_type = 'HAC', maxlags = None, use_correction = True)
print(Robust_Results.summary())
print('\n')
print('Standard Error of Estimate:', np.sqrt(Model1.mse_resid))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Sale_amount   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     69.36
# Date:                Sat, 12 Sep 2026   Prob (F-statistic):           1.35e-46
# Time:                        00:13:45   Log-Likelihood:                -2632.2
# No. Observations:                 211   AIC:                             5278.
# Df Residuals:                     204   BIC:                             5302.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5316.7711   5.31e+04      0.100      0.920   -9.94e+04     1.1e+05
# Beds        4295.9412   6182.492      0.695      0.488   -7893.836    1.65e+04
# Baths       2.301e+04   7554.332      3.045      0.003    8110.710    3.79e+04
# Sqft_home     79.5536      8.173      9.734      0.000      63.439      95.668
# Sqft_lot       0.4022      0.113      3.549      0.000       0.179       0.626
# Type        7.106e+04   4.65e+04      1.528      0.128   -2.07e+04    1.63e+05
# Age         -949.9364    173.916     -5.462      0.000   -1292.840    -607.033
# ==============================================================================
# Omnibus:                      128.630   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1492.249
# Skew:                           2.101   Prob(JB):                         0.00
# Kurtosis:                      15.332   Cond. No.                     6.90e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Sale_amount   R-squared:                       0.671
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     45.76
# Date:                Sat, 12 Sep 2026   Prob (F-statistic):           3.05e-35
# Time:                        00:13:45   Log-Likelihood:                -2632.2
# No. Observations:                 211   AIC:                             5278.
# Df Residuals:                     204   BIC:                             5302.
# Df Model:                           6
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   5316.7711   3.04e+04      0.175      0.861   -5.46e+04    6.52e+04
# Beds        4295.9412   6252.558      0.687      0.493   -8031.984    1.66e+04
# Baths       2.301e+04   6746.711      3.410      0.001    9703.066    3.63e+04
# Sqft_home     79.5536     13.933      5.710      0.000      52.082     107.026
# Sqft_lot       0.4022      0.251      1.601      0.111      -0.093       0.898
# Type        7.106e+04   2.45e+04      2.898      0.004    2.27e+04    1.19e+05
# Age         -949.9364    205.915     -4.613      0.000   -1355.932    -543.941
# ==============================================================================
# Omnibus:                      128.630   Durbin-Watson:                   1.342
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1492.249
# Skew:                           2.101   Prob(JB):                         0.00
# Kurtosis:                      15.332   Cond. No.                     6.90e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using None lags and with small sample correction
# [2] The condition number is large, 6.9e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Standard Error of Estimate: 64385.56831365046

# %% [markdown]
# ### Model 2: Sale_amount ~ Baths + Sqft_home + Sqft_lot + Age

# %%
# Obtatining linear regression equation with statiscally significant variables
Model2 = smf.ols('Sale_amount ~ Baths + Sqft_home + Sqft_lot + Age', data = myData).fit()
print(Model2.summary())

# Obtaining residuals
Model_Residuals = Model2.resid

import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.scatterplot(x =myData.Record, y = Model_Residuals, color = 'Chocolate')

# Add horizontal line at y=0
plt.axhline(y=0, color='black', linestyle='--')

# Set labels
ax.set(xlabel = 't', ylabel ='e');

# Show the plot
plt.show()

#Calculating robust standard error
Robust_Results = Model2.get_robustcov_results(cov_type = 'HAC', maxlags = None, use_correction = True)
print(Robust_Results.summary())
print('\n')
print('Standard Error of Estimate:', np.sqrt(Model2.mse_resid))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Sale_amount   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     103.1
# Date:                Sat, 12 Sep 2026   Prob (F-statistic):           4.56e-48
# Time:                        00:13:45   Log-Likelihood:                -2633.5
# No. Observations:                 211   AIC:                             5277.
# Df Residuals:                     206   BIC:                             5294.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.266e+04   2.14e+04      3.856      0.000    4.04e+04    1.25e+05
# Baths       2.512e+04   7274.409      3.453      0.001    1.08e+04    3.95e+04
# Sqft_home     80.7763      7.701     10.489      0.000      65.593      95.960
# Sqft_lot       0.4010      0.113      3.550      0.000       0.178       0.624
# Age         -944.1474    174.025     -5.425      0.000   -1287.246    -601.049
# ==============================================================================
# Omnibus:                      123.068   Durbin-Watson:                   1.344
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1330.675
# Skew:                           2.004   Prob(JB):                    1.12e-289
# Kurtosis:                      14.632   Cond. No.                     2.22e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            Sale_amount   R-squared:                       0.667
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     50.25
# Date:                Sat, 12 Sep 2026   Prob (F-statistic):           1.80e-29
# Time:                        00:13:45   Log-Likelihood:                -2633.5
# No. Observations:                 211   AIC:                             5277.
# Df Residuals:                     206   BIC:                             5294.
# Df Model:                           4
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8.266e+04   1.52e+04      5.445      0.000    5.27e+04    1.13e+05
# Baths       2.512e+04   6686.362      3.756      0.000    1.19e+04    3.83e+04
# Sqft_home     80.7763     12.361      6.535      0.000      56.405     105.148
# Sqft_lot       0.4010      0.254      1.579      0.116      -0.100       0.902
# Age         -944.1474    202.803     -4.655      0.000   -1343.983    -544.312
# ==============================================================================
# Omnibus:                      123.068   Durbin-Watson:                   1.344
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1330.675
# Skew:                           2.004   Prob(JB):                    1.12e-289
# Kurtosis:                      14.632   Cond. No.                     2.22e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using None lags and with small sample correction
# [2] The condition number is large, 2.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Standard Error of Estimate: 64469.56217745093

# %% [markdown]
# ### Model 3: ln(Sale_amount) ~ Baths + ln(Sqft_home) + ln(Sqft_lot) + Age

# %%
# Obtatining linear regression equation with statiscally significant variables and apply logarithmic transformation for large values
Model3 = smf.ols('np.log(Sale_amount) ~ Baths + np.log(Sqft_home) + np.log(Sqft_lot) + Age', data = myData).fit()
print(Model3.summary())

# Obtaining residuals
Model_Residuals = Model3.resid

import seaborn as sns
import matplotlib.pyplot as plt
ax = sns.scatterplot(x =myData.Record, y = Model_Residuals, color = 'Chocolate')

# Add horizontal line at y=0
plt.axhline(y=0, color='black', linestyle='--')

# Set labels
ax.set(xlabel = 't', ylabel ='e');

# Show the plot
plt.show()

#Calculating robust standard error
Robust_Results = Model3.get_robustcov_results(cov_type = 'HAC', maxlags = None, use_correction = True)
print(Robust_Results.summary())
print('\n')
print('Standard Error of Estimate:', np.sqrt(Model3.mse_resid))
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     np.log(Sale_amount)   R-squared:                       0.751
# Model:                             OLS   Adj. R-squared:                  0.747
# Method:                  Least Squares   F-statistic:                     155.7
# Date:                 Sat, 12 Sep 2026   Prob (F-statistic):           4.21e-61
# Time:                         00:13:45   Log-Likelihood:                 30.223
# No. Observations:                  211   AIC:                            -50.45
# Df Residuals:                      206   BIC:                            -33.69
# Df Model:                            4
# Covariance Type:             nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.7244      0.336     22.998      0.000       7.062       8.387
# Baths                 0.0995      0.025      3.973      0.000       0.050       0.149
# np.log(Sqft_home)     0.4612      0.053      8.780      0.000       0.358       0.565
# np.log(Sqft_lot)      0.1248      0.020      6.381      0.000       0.086       0.163
# Age                  -0.0045      0.001     -7.728      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                       18.864   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.533
# Skew:                          -0.540   Prob(JB):                     6.37e-07
# Kurtosis:                       4.441   Cond. No.                     1.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     np.log(Sale_amount)   R-squared:                       0.751
# Model:                             OLS   Adj. R-squared:                  0.747
# Method:                  Least Squares   F-statistic:                     73.69
# Date:                 Sat, 12 Sep 2026   Prob (F-statistic):           1.14e-38
# Time:                         00:13:45   Log-Likelihood:                 30.223
# No. Observations:                  211   AIC:                            -50.45
# Df Residuals:                      206   BIC:                            -33.69
# Df Model:                            4
# Covariance Type:                   HAC
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.7244      0.415     18.594      0.000       6.905       8.543
# Baths                 0.0995      0.024      4.227      0.000       0.053       0.146
# np.log(Sqft_home)     0.4612      0.058      7.968      0.000       0.347       0.575
# np.log(Sqft_lot)      0.1248      0.024      5.096      0.000       0.076       0.173
# Age                  -0.0045      0.001     -5.844      0.000      -0.006      -0.003
# ==============================================================================
# Omnibus:                       18.864   Durbin-Watson:                   1.576
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.533
# Skew:                          -0.540   Prob(JB):                     6.37e-07
# Kurtosis:                       4.441   Cond. No.                     1.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using None lags and with small sample correction
# [2] The condition number is large, 1.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
# Standard Error of Estimate: 0.21220918985403972

# %% [markdown]
# ### Cross Validation of All Models

# %%
# Evaluation
# K-fold validation method where k = 10
from sklearn.model_selection import KFold
splits = KFold(n_splits=10, shuffle=False).split(myData)
RMSE1 = []
RMSE2 = []
RMSE3 = []

MAE1 = []
MAE2 = []
MAE3 = []

MAPE1 = []
MAPE2 = []
MAPE3 = []

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

for train_index, val_index in splits:
    TData, VData = myData.iloc[train_index], myData.iloc[val_index]
    
    model1 = smf.ols('Sale_amount ~ Beds + Baths + Sqft_home + Sqft_lot + Type + Age', data=TData).fit()
    pred1 = model1.predict(VData)
    rmse1 = np.sqrt(mean_squared_error(VData['Sale_amount'], pred1))
    mae1 = mean_absolute_error(VData['Sale_amount'], pred1)
    mape1 = mean_absolute_percentage_error(VData['Sale_amount'], pred1)
    RMSE1.append(rmse1)
    MAE1.append(mae1)
    MAPE1.append(mape1)
    
    model2 = smf.ols('Sale_amount ~ Baths + Sqft_home + Sqft_lot + Age', data=TData).fit()
    pred2 = model2.predict(VData)
    rmse2 = np.sqrt(mean_squared_error(VData['Sale_amount'], pred2))
    mae2 = mean_absolute_error(VData['Sale_amount'], pred2)
    mape2 = mean_absolute_percentage_error(VData['Sale_amount'], pred2)
    RMSE2.append(rmse2)
    MAE2.append(mae2)
    MAPE2.append(mape2)

    model3 = smf.ols('np.log(Sale_amount) ~ Baths + np.log(Sqft_home) + np.log(Sqft_lot) + Age', data=TData).fit()
    pred3 = np.exp(model3.predict(VData))
    rmse3 = np.sqrt(mean_squared_error(VData['Sale_amount'], pred3))
    mae3 = mean_absolute_error(VData['Sale_amount'], pred3)
    mape3 = mean_absolute_percentage_error(VData['Sale_amount'], pred3)
    RMSE3.append(rmse3)
    MAE3.append(mae3)
    MAPE3.append(mape3)

rmse1 = np.mean(RMSE1)
rmse2 = np.mean(RMSE2)
rmse3 = np.mean(RMSE3)

mae1 = np.mean(MAE1)
mae2 = np.mean(MAE2)
mae3 = np.mean(MAE3)

mape1 = np.mean(MAPE1)
mape2 = np.mean(MAPE2)
mape3 = np.mean(MAPE3)

print('Model 1 RMSE:', rmse1)
print('Model 1 MAE:', mae1)
print('Model 1 MAPE:', mape1)
print('\n')
print('Model 2 RMSE:', rmse2)
print('Model 2 MAE:', mae2)
print('Model 2 MAPE:', mape2)
print('\n')
print('Model 3 RMSE:', rmse3)
print('Model 3 MAE:', mae3)
print('Model 3 MAPE:', mape3)
# Out:
# Model 1 RMSE: 65029.86318305427
# Model 1 MAE: 45056.799602763975
# Model 1 MAPE: 0.1951318147043367
#
#
# Model 2 RMSE: 64834.335829074924
# Model 2 MAE: 44709.80604017262
# Model 2 MAPE: 0.19418547298325028
#
#
# Model 3 RMSE: 56677.49727330704
# Model 3 MAE: 39895.53152514716
# Model 3 MAPE: 0.16982963076764046

# %% [markdown]
# ## Ensemble Tree Models

# %%
from pathlib import Path
import pandas as pd

data_path = Path("../../data/raw/Appendix_A_data.xlsx")

myData = pd.read_excel(data_path, sheet_name="House_Price")

myData.head()
# Out:
#    Record  Sale_amount  Sale_date  Beds  Baths  Sqft_home  Sqft_lot  \
# 0       1       295000 2016-05-31     5   3.00       2020   38332.8
# 1       2       240000 2016-06-20     4   2.00       1498   54014.4
# 2       3       385000 2016-05-31     5   4.00       4000   85813.2
# 3       4       268000 2016-04-12     3   2.50       2283  118918.8
# 4       5       186000 2016-04-05     3   1.25       1527   15681.6
#
#             Type  Build_year      Town             University
# 0  Single Family        1976  Ames, IA  Iowa State University
# 1  Single Family        2002  Ames, IA  Iowa State University
# 2  Single Family        2001  Ames, IA  Iowa State University
# 3  Single Family        1972  Ames, IA  Iowa State University
# 4  Single Family        1975  Ames, IA  Iowa State University

# %%
# Filter dataset for Iowa State University
myData = myData.query("University =='Iowa State University'")

# Convert house type into dummy variable, Single Family = 1, Non Single Family = 0
myData['Type'] = myData['Type'].apply(lambda x: 1 if x == 'Single Family' else 0)

# Determining age of home
from datetime import datetime
myData['Age'] = datetime.now().year - myData['Build_year']

# Drop town and university columns and all categorial variable columns with more than two values
myData = myData.drop(['Record', 'Sale_date', 'Build_year', 'Town', 'University'], axis=1)

myData.head()
# Out:
#    Sale_amount  Beds  Baths  Sqft_home  Sqft_lot  Type  Age
# 0       295000     5   3.00       2020   38332.8     1   50
# 1       240000     4   2.00       1498   54014.4     1   24
# 2       385000     5   4.00       4000   85813.2     1   25
# 3       268000     3   2.50       2283  118918.8     1   54
# 4       186000     3   1.25       1527   15681.6     1   51

# %%
# 70% training, 30% test, random state 321
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(myData.drop('Sale_amount', axis = 1), 
                                                    myData.Sale_amount, 
                                                    test_size = 0.30, 
                                                    random_state = 321)

# Look if split is correct
print(len(X_train))
print(len(X_test))
# Out:
# 147
# 64

# %% [markdown]
# ### Model 1: Bagging Tree

# %%
# Random forest regressor for ensemble trees
from sklearn.ensemble import RandomForestRegressor

Bagging_model = RandomForestRegressor(random_state = 321)

# Bagging tree parameters
paramGrid = {'n_estimators': [100, 250, 500, 1000], 
             'max_depth': range(1, 10 + 1), 
             'max_features': [None]}

# 10 fold validation
from sklearn.model_selection import GridSearchCV

search = GridSearchCV(Bagging_model, 
                      paramGrid, 
                      cv = 10, 
                      scoring = 'neg_root_mean_squared_error', 
                      n_jobs = 1)

# %%
Bagging_tree = search.fit(X_train, y_train)
pd.DataFrame(Bagging_tree.cv_results_).sort_values('rank_test_score')[['param_n_estimators', 'param_max_depth','mean_test_score', 'rank_test_score']].head(10)
# Out:
#     param_n_estimators  param_max_depth  mean_test_score  rank_test_score
# 34                 500                9    -62934.869503                1
# 32                 100                9    -62964.796114                2
# 35                1000                9    -63004.242075                3
# 38                 500               10    -63023.737570                4
# 39                1000               10    -63039.976138                5
# 36                 100               10    -63126.952901                6
# 28                 100                8    -63164.766899                7
# 30                 500                8    -63218.684164                8
# 33                 250                9    -63284.955959                9
# 31                1000                8    -63343.455919               10

# %%
Bagging_tree.best_estimator_
# Out:
# RandomForestRegressor(max_depth=9, max_features=None, n_estimators=500,
#                       random_state=321)

# %%
importances = pd.DataFrame({
    'feature': X_train.columns, 
    'importance': Bagging_tree.best_estimator_.feature_importances_
})

import seaborn as sns
sns.barplot(y = 'feature', 
            x = 'importance', 
            data = importances.sort_values('importance', ascending = False));

# %%
# Evaluation
testPredictions = Bagging_tree.predict(X_test)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

print('RMSE:', np.sqrt(mean_squared_error(y_test, testPredictions)))
print('MAE:', mean_absolute_error(y_test, testPredictions))
print('MAPE:', mean_absolute_percentage_error(y_test, testPredictions))
# Out:
# RMSE: 64555.78973220282
# MAE: 39467.92781633769
# MAPE: 0.17397341543932393

# %% [markdown]
# ### Model 2: Random Forest

# %%
# Random forest regressor for ensemble trees
from sklearn.ensemble import RandomForestRegressor

RF_model = RandomForestRegressor(random_state = 321)

# Random Forest parameters
paramGrid = {'n_estimators': [100, 250, 500, 1000], 
             'max_depth': range(1, 10 + 1), 
             'max_features': ["sqrt"]}

# 10 fold validation
from sklearn.model_selection import GridSearchCV

search = GridSearchCV(RF_model, 
                      paramGrid, 
                      cv = 10, 
                      scoring = 'neg_root_mean_squared_error', 
                      n_jobs = 1)

# %%
RF_tree = search.fit(X_train, y_train)
pd.DataFrame(RF_tree.cv_results_).sort_values('rank_test_score')[['param_n_estimators', 'param_max_depth','mean_test_score', 'rank_test_score']].head(10)
# Out:
#     param_n_estimators  param_max_depth  mean_test_score  rank_test_score
# 32                 100                9    -62723.146281                1
# 28                 100                8    -63285.617710                2
# 36                 100               10    -63599.803428                3
# 38                 500               10    -63607.807353                4
# 39                1000               10    -63694.804779                5
# 37                 250               10    -63842.910451                6
# 29                 250                8    -63849.510373                7
# 35                1000                9    -64108.626466                8
# 34                 500                9    -64121.828382                9
# 27                1000                7    -64201.640787               10

# %%
RF_tree.best_estimator_
# Out:
# RandomForestRegressor(max_depth=9, max_features='sqrt', random_state=321)

# %%
importances = pd.DataFrame({
    'feature': X_train.columns, 
    'importance': RF_tree.best_estimator_.feature_importances_
})

import seaborn as sns
sns.barplot(y = 'feature', 
            x = 'importance', 
            data = importances.sort_values('importance', ascending = False));

# %%
# Evaluation
testPredictions = RF_tree.predict(X_test)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

print('RMSE:', np.sqrt(mean_squared_error(y_test, testPredictions)))
print('MAE:', mean_absolute_error(y_test, testPredictions))
print('MAPE:', mean_absolute_percentage_error(y_test, testPredictions))
# Out:
# RMSE: 57218.84034332497
# MAE: 36001.76788943625
# MAPE: 0.16368823528219234

# %% [markdown]
# ### Model 3: Boosting Tree

# %%
from sklearn.ensemble import GradientBoostingRegressor

Boosting_model = GradientBoostingRegressor(random_state = 321)

paramGrid = {'n_estimators': [100, 250, 500, 1000], 
             'max_depth': range(1, 10 + 1)}

from sklearn.model_selection import GridSearchCV

search = GridSearchCV(Boosting_model, 
                      paramGrid, 
                      cv = 10, 
                      scoring = 'neg_root_mean_squared_error', 
                      n_jobs = 1)

# %%
Boosting_tree = search.fit(X_train, y_train)
pd.DataFrame(Boosting_tree.cv_results_).sort_values('rank_test_score')[['param_n_estimators', 'param_max_depth','mean_test_score', 'rank_test_score']].head(10)
# Out:
#     param_n_estimators  param_max_depth  mean_test_score  rank_test_score
# 4                  100                2    -62270.226529                1
# 5                  250                2    -63660.262063                2
# 6                  500                2    -65292.378273                3
# 0                  100                1    -65499.591026                4
# 7                 1000                2    -65985.371333                5
# 13                 250                4    -67511.882487                6
# 15                1000                4    -67512.170360                7
# 14                 500                4    -67513.258146                8
# 12                 100                4    -67734.575497                9
# 1                  250                1    -68290.084379               10

# %%
Boosting_tree.best_estimator_
# Out:
# GradientBoostingRegressor(max_depth=2, random_state=321)

# %%
importances = pd.DataFrame({
    'feature': X_train.columns, 
    'importance': Boosting_tree.best_estimator_.feature_importances_
})

import seaborn as sns
sns.barplot(y = 'feature', 
            x = 'importance', 
            data = importances.sort_values('importance', ascending = False));

# %%
# Evaluation
testPredictions = Boosting_tree.predict(X_test)

from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

print('RMSE:', np.sqrt(mean_squared_error(y_test, testPredictions)))
print('MAE:', mean_absolute_error(y_test, testPredictions))
print('MAPE:', mean_absolute_percentage_error(y_test, testPredictions))
# Out:
# RMSE: 76603.7896692011
# MAE: 42463.15736203704
# MAPE: 0.1822608656890588

# %% [markdown]
# ## Portfolio Visualizations
#
# The following visualizations were regenerated from the validated reconstruction
# for use in the repository and portfolio case study. These figures improve
# presentation quality without changing the original analytical workflow or results.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

portfolio_images = Path("../../images/portfolio")
portfolio_images.mkdir(parents=True, exist_ok=True)

fig, ax = plt.subplots(figsize=(10, 6))

ax.hist(myData["Sale_amount"], bins=20, edgecolor="black")

ax.set_title("Distribution of Residential Sale Prices — Ames, Iowa")
ax.set_xlabel("Sale Price (USD)")
ax.set_ylabel("Number of Properties")
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

fig.tight_layout()
fig.savefig(
    portfolio_images / "sale_price_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

rf_importance = pd.Series(
    RF_tree.best_estimator_.feature_importances_,
    index=X_train.columns
).sort_values(ascending=True)

fig, ax = plt.subplots(figsize=(10, 6))

ax.barh(rf_importance.index, rf_importance.values)

ax.set_title("Random Forest Feature Importance")
ax.set_xlabel("Importance")
ax.set_ylabel("Predictor")

fig.tight_layout()

fig.savefig(
    portfolio_images / "random_forest_feature_importance.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

models = [
    "Linear Reg 1",
    "Linear Reg 2",
    "Linear Reg 3",
    "Bagging",
    "Random Forest",
    "Gradient Boosting"
]

rmse = [65029.86, 64834.34, 56677.50, 64555.79, 57218.84, 76603.79]
mae  = [45056.80, 44709.81, 39895.53, 39467.93, 36001.77, 42463.16]
mape = [19.51, 19.42, 16.98, 17.40, 16.37, 18.23]

x = np.arange(len(models))
width = 0.35

fig, (ax1, ax2) = plt.subplots(
    2,
    1,
    figsize=(12, 9),
    sharex=True,
    gridspec_kw={"height_ratios": [2, 1]}
)

# RMSE and MAE
ax1.bar(x - width/2, rmse, width, label="RMSE")
ax1.bar(x + width/2, mae, width, label="MAE")

ax1.set_title("Residential Property Model Performance")
ax1.set_ylabel("Prediction Error (USD)")
ax1.legend()

# MAPE
ax2.bar(x, mape)

ax2.set_ylabel("MAPE (%)")
ax2.set_xlabel("Model")
ax2.set_xticks(x)
ax2.set_xticklabels(models, rotation=30, ha="right")

fig.tight_layout()

fig.savefig(
    portfolio_images / "model_performance_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
